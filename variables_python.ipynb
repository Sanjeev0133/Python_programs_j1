# %% [markdown]
# # variable in python
# 1. variables is memory allocation to a value
# 2. examples are name-"shivaji" , age-26 , salary-20000
#
# ## key points to define variabales
# 1. do not start with digit
# 2. variables do not allowed special characters
# 3. do not use keywords as a variables

# %%
name="vikas"
age=20
salary=45000.65
print(name)
print(age)
print(salary)
# Out:
# vikas
# 20
# 45000.65

# %%
name1="shivaji"
print(name1
    )
# Out:
# shivaji

# %%
whilel= "shivaji"
print(whilel)
# Out:
# shivaji
